# %%
# ASSIGNMENT-1/2
#First Tuple

# %%
t1=(10,20,30)
t2=(40,50,60)
t_combine = t1+t2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
type(t_combine)
# Out:
# tuple

# %%
#b. Repeat t_combine 3 times 
t_combine=t_combine + t_combine + t_combine
print(t_combine)
type(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# tuple

# %%
#c.access the third element from t_combine

t_combine[2]
# Out:
# 30

# %%
#d. access the first three elements from t_combine
t_combine[0:3]
# Out:
# (10, 20, 30)

# %%
#e. access the last three elements of t_combine
l=len(t_combine)
print(l)
t_combine[15:18]
# Out:
# 18
# (40, 50, 60)

# %%
#2.Create a list my_list as specified
my_list=[(1,2,3),("a", "b","c"),(True,False)]
print(my_list)
type(my_list)
l=len(my_list)
l
# Out:
# [(1, 2, 3), ('a', 'b', 'c'), (True, False)]
# 3

# %%
# 3.Append a new tuple (1, 'a', True) to my_list
my_list.append((1,'a',True))
print(my_list)
# Out:
# [(1, 2, 3), ('a', 'b', 'c'), (True, False), (1, 'a', True)]

# %%
#4.a Create a Dictionary 'fruit' where the first key is 'Fruit' and the values are as given
#4.b. key is cost and corresponding values
fruit={"Fruit":("Apple", "Banana", "Mango","Guava"),"Cost":(85,54,120,70)}
type(fruit)
print(fruit)
# Out:
# {'Fruit': ('Apple', 'Banana', 'Mango', 'Guava'), 'Cost': (85, 54, 120, 70)}

# %%
#4.c. Extract all the keys from 'fruit'

fruit['Fruit']
# Out:
# ('Apple', 'Banana', 'Mango', 'Guava')

# %%
# 4.c. Extract all the keys from 'fruit'
fruit['Cost']
# Out:
# (85, 54, 120, 70)

# %%
#4.d. Extract all the values from 'fruit'
print(fruit['Fruit'][-1])
print(fruit['Fruit'][-2])
print(fruit['Fruit'][0])
print(fruit['Fruit'][1])
print(fruit['Cost'][0])
print(fruit['Cost'][1])
print(fruit['Cost'][2])
print(fruit['Cost'][3])
# Out:
# Guava
# Mango
# Apple
# Banana
# 85
# 54
# 120
# 70

# %%
# 5.set named 'my_set' with given values and print the result
my_set = {1,1,"a","a",True,True}
print(my_set)
# Out:
# {1, 'a'}

# %%
# 5.set named 'my_set' with given values and print the result
my_set2 = {1,1,"a","a",False,False}
print(my_set2)
# Out:
# {False, 1, 'a'}

# %%
# 5.set named 'my_set' with given values and print the result
my_set3 = {1,1,"a","a",False,True}
print(my_set3)
# Out:
# {False, 1, 'a'}
